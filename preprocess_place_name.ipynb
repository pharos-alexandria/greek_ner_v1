# %%
# TODO: add https://en.wikipedia.org/wiki/List_of_Greek_place_names

# %%
import json

# %%
with open("pleiades-places-latest.json", "rb") as fo:
    pleiades = json.load(fo)

# %%
len(pleiades["@graph"])
# Out:
# 37500

# %%
def is_greek_char(char: str):
    if 880 <= ord(char) <= 1023 or 7936 <= ord(char) <= 8191:
        return True
    return False

is_greek_char("ά")
# Out:
# True

# %%
pleiades_names = list()
for item in pleiades["@graph"]:
    for name in item["names"]:
        # "ancient greek" only in name["description"] 55 times, so not reliable; "greek" 129
        # https://www.ssec.wisc.edu/~tomw/java/unicode.html
        # Ancient Greek hex range: 0370—03FF == 880-1023
        # Greek Extended: 1F00—1FFF == 7936-8191
        # if all(), then 1329 Greek names are found
        # if any(), then 1585; not a big diff, use the ones we know are right
        if name["attested"] and all([is_greek_char(x) for x in name["attested"]]):
                pleiades_names.append(name["attested"])
print("Total:", len(pleiades_names))
# Out:
# Total: 1329

# %%
# also "place names" from wiki: https://en.wikipedia.org/wiki/List_of_Greek_place_names
with open("f.txt") as fo:
    wiki_names = fo.readlines()
wiki_names = [s.strip() for s in place_names]

# %%
len(wiki_names)
# Out:
# 832

# %%
print(wiki_names[:3])
# Out:
# ['Ἄβδηρα', 'Ἄβυδος', 'Ἀγαθὴ Τύχη']

# %%
names = pleiades_names + wiki_names
print(len(names))
# Out:
# 2161

# %%
# remove multiword place names
# this can be reenabled later
names = [n for n in names if len(n.split()) == 1]
print(len(names))
# Out:
# 2135

# %%
# trim suffix of each word unless short
# doing this as a naive match to declined forms in real texts
names_new = list()
for name in names:
    femenine_endings = ["ά", "α", "η", "ή"]
    masculine_neuter_endings = ["ος", "ός", "ον", "όν"]
    consonants = list("βγδεζθκλμνξπρσςτυφχψω")
    if not len(name) > 3:
        names_new.append(name)
    elif any([end for end in femenine_endings if name.endswith(end)]):
        names_new.append(name[:-1])
    elif any([end for end in masculine_neuter_endings if name.endswith(end)]):
        names_new.append(name[:-2])
    elif any([end for end in consonants if name.endswith(end)]):
        names_new.append(name)
    else:
        names_new.append(name)
print(names_new)
# Out:
# ['Μαινάκῃ', 'Ὠρητανοί', 'Πιτυοῦσσαι', 'Σκομβραρί', 'Ἀβίλυχ', 'Ἥρας', 'Λίξ', 'Καρμανί', 'Ζουχάββαρι', 'Κεδρωσί', 'Γαδρωσί', 'Γεδρωσί', 'Ὀάρακτ', 'Προφθασί', 'Σάρνι', 'Κώφας', 'Ὠγυρις', 'Ὀργάν', 'Νόαρ', 'Βήθηλά', 'Βήθηγ', 'Κουκονήσι', 'Δισπηλιό', 'Ἰάνουκλ', 'Στροφάδες', 'Πλωταί', 'Στροφαδεύς', 'Μασσαλί', 'Νεμαύσ', 'Βιντιμιλίω', 'Ἀλβίγγαυν', 'Ὀξύβιοι', 'Βαβυλωνί', 'Ἐλυμαίς', 'Εὐφράτης', 'Χοάσπης', 'Σοῦσ', 'Φουρνί', 'Σώζουσ', 'Βάρκ', 'Βερενίκ', 'Κυρηναί', 'Εὐεσπερίδας', 'Παλίουρ', 'Φιδεντί', 'Ἴνσουβροι', 'Λιγυστικὴ', 'Πάρμ', 'Ῥήγι', 'Τικῖν', 'Ἰκτούμουλαι', 'Ἀλαλαίου', 'Αὐαλίτης', 'Κασσανῖται', '᾿οπιτέργι', 'Σάπις', 'Ὁμηρίται', 'Μαλίχου', 'Μιναῖοι', 'Ὀφρύνει', 'Ἀλλιανοί', 'Πακτωλὸς', 'Πιτάν', 'Πολυμήδει', 'Ψύρ', 'Ῥοίτει', 'Σάρδεις', 'Σατνιόεις', 'Σκάμανδρ', 'Σίγει', 'Σιμόεις', 'Σίπυλ', 'Σμύρν', 'Τευθρανί', 'Θήβ', 'Θύμβρι', 'Τμῶλ', 'Τρῳάς', 'Ἀρδύνι', 'Ἰτών', 'Κάναι', 'Κλεανδρί', 'Πύλαι', 'Αἴγιλ', 'Ὤγυλ', 'Καμηλονήσι', 'Αἰγιαλὸς', 'Ἀχαί', 'Αἰγιάλει', 'Ἀχαιοί', 'Ἀχέρων', 'Αἰγαί', 'Αἰγειρ', 'Αἴγι', 'Γερανείᾳ', 'Αἰγόσθεν', 'Ἀκρίαι', 'Ακροκόρινθ', 'Ἀπεροπί', 'Φουκάς', 'Ἀραχναῖ', 'Αραχναίο', 'Ἄραξ', 'Ἀρκαδί', 'Ἄργ', 'Ἀροάνι', 'Ἀρτεμίσι', 'Ἀσέ', 'Ἀσίν', 'Ἀσιναί', 'Ἀσωπὸς', 'Βολιναῖ', 'Χάα', 'Χάραδρ', 'Αἰγιαλεῖς', 'Αἰγιαλεὺς', 'Σικυωνίᾳ', 'Κόρινθ', 'Κύθηρ', 'Δώρι', 'Ἠλεῖοι', 'Ἐπιδήλι', 'Ἐπιτάλι', 'Θρύ', 'Ἐρινεὸνς', 'Ἐρύμανθ', 'Ἐρύμανθ', 'Εὔα', 'Ευρώτας', 'Γερόντει', 'Γερόνθραι', 'Γλυππί', 'Ἁλιεῖς', 'Ἑλισσών', 'Ἑρμιὼν', 'Ἑρμιόν', 'Ὅρμιν', 'Ὑπερτελέατ', 'Καλαύρει', 'Καλαυρί', 'Ἐρέχθει', 'Ὀβιδιακηνοὶ', 'Σιττακηνοὶ', 'Ἄμαστρις', 'Ἀμνίας', 'Βιθύνι', 'Γάγγρ', 'Κρῶμν', 'Μαριανδυνοί', 'Παφλαγονί', 'Πομπηιόπολις', 'Ἀντικείτ', 'Κῆποι', 'Κιμμερικὸν', 'Μυρμήκι', 'Νύμφαι', 'Παντικάπαι', 'Παρθένι', 'Πατραεύς', 'Φαναγόρει', 'Σινδικῇ', 'Σινδοὶ', 'Θεοδοσί', 'Τυράμβ', 'Ἀλβανοὶ', 'Συρεαν', 'Τρικομί', 'Χαμανηνὴ', 'Γαρσάουρ', 'Σαραουηνὴ', 'Τάουι', 'Τροκμοὶ', 'Δρυνέμετ', 'Μιθριδάτι', 'Ἀργαῖ', 'Ἀριαράθει', 'Κόμαν', 'Καταονίᾳ', 'Κουλουπην', 'Μάζακ', 'Φίαρ', 'Ἀμλαδέων', 'Ἀντίφελλ', 'Κελαιναί', 'Ἀφροδισιάς', 'Νινό', 'Σταυρόπολις', 'Ἀφροδεισιάς', 'Ἀττάλει', 'Αὔνησις', 'Κολοσσην', 'Ἁμαξί', 'Κάλυνδ', 'Κώρυκ', 'Λίμυρ', 'Πεδνηλισσ', 'Σέλγ', 'Σίδ', 'Τραπεζόπολις', 'Ξάνθ', 'Φθειροφάγοι', 'Σινώπ', 'Τάοχοι', 'Τιβαρηνοί', 'Τραπεζοῦς', 'Κάλλατις', 'Γέται', 'Νάπαρις', 'Πυρετ', 'Λίβνι', 'Λάρισ', 'Νόης', 'Ἀγάθυρσοι', 'Χάραξ', 'Χερρόνησ', 'Χερσών', 'Κρόβυζοι', 'Ὕπανις', 'Καρκινῖτις', 'Παντικάπης', 'Τάφριοι', 'Τύρας', 'Τυρεγέται', 'Τραπεζοῦς', 'Κιμμέριοι', 'Οὐέλι', 'Λίμν', 'Ἰγιλγιλί', 'Αἰγίμουρ', 'Ἰουνωνί', 'Νεάπολις', 'Τῶκαι', 'Τύνης', 'Τύνις', 'Περίτας', 'Παλαίβυβλ', 'Φοινίκ', 'Σεβαστ', 'Συχέμ', 'τραχῶνες', 'Τύρ', 'Ἀζωτ', 'Ἀσκάλων', 'Ἐλευθερόπολις', 'Γάζ', '῾ιερικοῦς', 'Ἰαμνεί', 'Ἱεροσόλυμ', 'Αἰλἴ', 'Ἰόππ', 'Ἰόπ', 'Ἰουδαί', 'Διόσπολις', 'Μοασάδ', 'Ἀντιπατρίς', 'Ῥαφί', 'Ῥινοκόρουρ', 'Σοκχωθ', 'Σοκχωθ', 'Συκαμαζῶν', 'Φιλαδέλφει', 'Ἀρσινό', 'Γερόνησ', 'Καρπασί', 'Κλεῖδες', 'Βοόσουρ', 'Ταμασσ', 'Ζεφύρι', 'Ἀδυρμαχίδαι', 'Ἄνθυλλ', 'Μαγδωλ', 'Μένδης', 'Νεῖλ', 'Σάι', 'Στρογγύλ', 'Καλλιστ', 'Κάρυστ', 'Κεγχρεαί', 'Κερύνει', 'Κλείτωρ', 'Κνάκαλ', 'Κρανά', 'Κρᾶθις', 'Κροκέαι', 'Κυλλήν', 'Κυλλήν', 'Θῶνις', 'Ξόις', 'Κολχονουφίτης', 'Ἄκωρις', 'Τριπυργί', 'Τυρμεῖδαι', 'Δίκτ', 'Ἄνδρ', 'Μαλάξ', 'Χάλκ', 'Χαλκί', 'Χάλκ', 'Χάλκει', 'Γαϊδουρονήσι', 'Κρήτ', 'Δικτύνναι', 'Δρῆρ', 'Γόρτυν', 'Γύαρ', 'Ἡράκλει', 'Κάνταν', 'Κάρπαθ', 'Κάσ', 'Κίμωλ', 'Λάγουσ', 'Λατώ', 'Λεβήν', 'Λερ', 'Λευκ', 'Λύκτ', 'Λύττ', 'Ὠλίαρ', 'Ὄλους', 'Πατέλλ', 'Πρινιάς', 'Ῥιζηνί', 'Πολυρρήνιοι', 'Πρεπέσινθ', 'Δεσποτικό', 'Ῥόδ', 'Σέριφ', 'Σίκιν', 'Σίφν', 'τῆν', 'Τήν', 'Ἄξ', 'Ὄαξ', 'Ῥαμβακί', 'Ἀπαρύται', 'Ἀραβῖται', 'Ἄρβιες', 'Ὑπάσιοι', 'Βανδοβηνὴ', 'Βαργόσ', 'Βουκεφάλ', 'Χααρηνὴ', 'Δαράδραι', 'Γάζ', 'Γλαυγανῖκαι', 'Ἠμωδὰ', 'Ὑδάσπης', 'Βιδάσπης', 'Ὑδραώτης', 'Ὑάρωτις', 'Μαράκανδ', 'Μασόγ', 'Μουσικανοι', 'Ἀλάβανδ', 'Νυσαῖοι', 'Ἄλινδ', 'Ἀμυζὼν', 'Βούριν', 'Ὠρεῖται', 'Χαλκήτορες', 'Κνίδ', 'Νότι', 'Δῆλ', 'Διαβῆται', 'Ἰουστινιανόπολις', 'Δρέκαν', 'Ἔφεσ', 'Εὔρωμ', 'Ἁλικαρνασσ', 'Ἡράκλει', 'Ὑβάνδ', 'Ἰασὸς', 'Πλάτ', 'Κέγχρι', 'Λάβρανδ', 'Λέβινθ',  ...
